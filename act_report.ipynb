# %% [markdown]
# # Data Wrangling project
# ## Table of Contents
# 1-[Introduction]
#
# 2-[Questions]
#
# 3-[Exploratory Data]

# %% [markdown]
# ![Untitle2.jpg](attachment:Untitle2.jpg)

# %% [markdown]
# The dataset that you will be wrangling (and analyzing and visualizing) is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because "they're good dogs Brent." WeRateDogs has over 4 million followers and has received international media coverage.

# %% [markdown]
# This archive contains basic tweet data (tweet ID, timestamp, text, etc.) for all 5000+ of their tweets as they stood on August 1, 2017. More on this soon.

# %% [markdown]
# # Questions:
#
# ***Ratings of dogs based on type***
#
# ***Best dog according to rating***
#
# ***Tweets based on hour of the day***
#
# ***Tweets based on the days of the week***
#
# ***Tweets based on month***
#
# ***The 10 most rated dog***

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ![Untitle1.jpg](attachment:Untitle1.jpg)

# %% [markdown]
# ### Basic plots based on the available columns
# #### Plot 1
# **The most comon  dogs**

# %% [markdown]
# ![plot1.jpg](attachment:plot1.jpg)

# %% [markdown]
# ### Conclusions
# ___The above graph shows that most of the dogs belong to pupper category. doggo,puppo and doggo,floofer has the least no of dogs___

# %% [markdown]
# ### Plot 2
# ***The average rating of dogs based on dog_stage***

# %% [markdown]
# ![plot2.jpg](attachment:plot2.jpg)

# %% [markdown]
# ## Conclusions
# __The doggo,puppo category hav  highest average rating and highest deviation__

# %% [markdown]
# ### Plot 3
# #### No of tweets based on month

# %% [markdown]
# ![plot3.jpg](attachment:plot3.jpg)

# %% [markdown]
# The above plot shows that December and November are the months having he most no of tweets. August has the least no of tweets.

# %% [markdown]
# ### Plot 4
# ##### No of tweets based on the day of the week

# %% [markdown]
# ![plot4.jpg](attachment:plot4.jpg)

# %% [markdown]
# ***he above graph shows that most of the tweets are done on Tuseday and gradually decreasing by the end of the week***

# %% [markdown]
# ### Plot 5
# ##### No of tweets based on hour of the Day

# %% [markdown]
# ![plot5.jpg](attachment:plot5.jpg)

# %% [markdown]
# The above graph shows that most of the tweets are done early in the morning or in the evening. The time between 5AM and 2PM has the least number of tweets

# %% [markdown]
# ### Plot 6
#
# #### Top 10 most common names of Dogs

# %% [markdown]
# ![plot6.jpg](attachment:plot6.jpg)

# %% [markdown]
# ***The above graph shows that the most common names used for dogs is Pickles , Loki and Sampson  followed by Bo, Penny and others***

# %% [markdown]
# ### Plot 7
# #### Top 10 most rated dogs

# %% [markdown]
# ![plot7.jpg](attachment:plot7.jpg)

# %% [markdown]
# ![7.jpg](attachment:7.jpg)

# %% [markdown]
# ***The highest 10 dogs rate Cassie , Smiley ,Doobert,Gabe,Sundance,Sunny,Bo,Ollie,Laika***

# %% [markdown]
# ### Plot 8
# #### Pi char
# ***The most common dog***

# %% [markdown]
# ![pi.jpg](attachment:pi.jpg)

# %% [markdown]
# ***Pupper is the most common dog in dog_stage***
